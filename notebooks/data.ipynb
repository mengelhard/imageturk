# %%
import numpy as np
import pandas as pd
import ast

# %%
DATA_DIR = '/Users/mme/data/imageturk/'

# %%
fn = 'imageturk_smoker/i(m)ageTurk (Smoker)_February 12, 2020_11.07.csv'

# %%
df = pd.read_csv(DATA_DIR + fn, header=[0, 1, 2])
df.head(10)
# Out:
#                                              StartDate  \
#                                             Start Date
#   {"ImportId":"startDate","timeZone":"America/Denver"}
# 0                                2019-04-29 06:14:41
# 1                                2019-05-01 10:51:28
# 2                                2019-09-25 09:56:10
# 3                                2019-09-25 09:59:17
# 4                                2019-09-26 13:51:37
# 5                                2019-12-23 14:20:36
# 6                                2019-12-23 14:20:45
# 7                                2019-12-23 14:21:03
# 8                                2019-12-23 14:21:14
# 9                                2019-12-23 15:18:58
#
#                                              EndDate                Status  \
#                                             End Date         Response Type
#   {"ImportId":"endDate","timeZone":"America/Denver"} {"ImportId":"status"}
# ...

# %%
coldict = {ast.literal_eval(x[2])['ImportId']: x[1] for x in df.columns.values}
colnames = [ast.literal_eval(x[2])['ImportId'] for x in df.columns.values]
df.columns = colnames
len(colnames), len(np.unique(colnames))
# Out:
# (222, 222)

# %%
df.head()
# Out:
#              startDate              endDate          status  progress  \
# 0  2019-04-29 06:14:41  2019-04-29 06:17:23  Survey Preview       100
# 1  2019-05-01 10:51:28  2019-05-01 10:54:05  Survey Preview       100
# 2  2019-09-25 09:56:10  2019-09-25 10:11:25  Survey Preview       100
# 3  2019-09-25 09:59:17  2019-09-25 10:48:30  Survey Preview       100
# 4  2019-09-26 13:51:37  2019-09-26 13:59:50  Survey Preview       100
#
#    duration  finished         recordedDate          _recordId  \
# 0       162      True  2019-04-29 06:17:37  R_1o0cY6Yyc9vylyk
# 1       156      True  2019-05-01 10:54:18  R_3UDiL4ydzeHkfiV
# 2       915      True  2019-09-25 10:11:52  R_1feBbBFhN0reHPg
# 3      2952      True  2019-09-25 10:48:44  R_2axDnCdu7uL1tFD
# 4       492      True  2019-09-26 14:00:19  R_2Vl5AI8vcrGkkmg
#
#   distributionChannel userLanguage  ... QID125_TEXT QID122 QID115  \
# 0             preview           EN  ...         NaN    NaN    NaN
# ...

# %%
df.columns.values
# Out:
# array(['startDate', 'endDate', 'status', 'progress', 'duration',
#        'finished', 'recordedDate', '_recordId', 'distributionChannel',
#        'userLanguage', 'QID132', 'QID131', 'QID130', 'QID106_TEXT',
#        'QID2_FILE_ID', 'QID2_FILE_NAME', 'QID2_FILE_SIZE',
#        'QID2_FILE_TYPE', 'QID90_FILE_ID', 'QID90_FILE_NAME',
#        'QID90_FILE_SIZE', 'QID90_FILE_TYPE', 'QID4_FILE_ID',
#        'QID4_FILE_NAME', 'QID4_FILE_SIZE', 'QID4_FILE_TYPE',
#        'QID91_FILE_ID', 'QID91_FILE_NAME', 'QID91_FILE_SIZE',
#        'QID91_FILE_TYPE', 'QID6_FILE_ID', 'QID6_FILE_NAME',
#        'QID6_FILE_SIZE', 'QID6_FILE_TYPE', 'QID92_FILE_ID',
#        'QID92_FILE_NAME', 'QID92_FILE_SIZE', 'QID92_FILE_TYPE',
#        'QID7_FILE_ID', 'QID7_FILE_NAME', 'QID7_FILE_SIZE',
#        'QID7_FILE_TYPE', 'QID93_FILE_ID', 'QID93_FILE_NAME',
#        'QID93_FILE_SIZE', 'QID93_FILE_TYPE', 'QID8_FILE_ID',
#        'QID8_FILE_NAME', 'QID8_FILE_SIZE', 'QID8_FILE_TYPE',
# ...

# %%
(df['QID108_TEXT'] == 'NaN').value_counts()
# Out:
# /opt/anaconda3/envs/tf-1.15/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# False    758
# Name: QID108_TEXT, dtype: int64

# %%
df['distributionChannel'].value_counts()
# Out:
# anonymous    588
# qr           161
# preview        9
# Name: distributionChannel, dtype: int64

# %%
import matplotlib.pyplot as plt

image_cols = [x.split('_')[0] for x in df.columns.values if (x.split('_')[-1] == 'SIZE')]
image_sizes = np.any(np.array([df[x + '_FILE_SIZE'].values for x in image_cols]) < 1e5, axis=0)

pd.value_counts(image_sizes)
# Out:
# /opt/anaconda3/envs/tf-1.15/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in less
#   after removing the cwd from sys.path.
# False    693
# True      65
# dtype: int64

# %%
image_cols
# Out:
# ['QID2',
#  'QID90',
#  'QID4',
#  'QID91',
#  'QID6',
#  'QID92',
#  'QID7',
#  'QID93',
#  'QID8',
#  'QID94',
#  'QID9',
#  'QID95',
#  'QID10',
#  'QID96',
#  'QID11',
#  'QID97']

# %%
df['QID84_1'].value_counts()
# Out:
# Average           75
# Above             53
# Slightly Above    44
# Far Above         18
# Below             16
# Slightly Below    16
# Far Below          3
# Name: QID84_1, dtype: int64
